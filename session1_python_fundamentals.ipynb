# %% [markdown]
# <a href="https://colab.research.google.com/github/PrabhatKumarArya/CatPhotosApp-/blob/main/session1_python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,11,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %%
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
print({'Name':'Prabhat','Gender':'Male'})
# Out:
# {'Name': 'Prabhat', 'Gender': 'Male'}

# %%
type([1,2,3])
# Out:
# list

# %%
name = 'nitish'
print(name)
# Out:
# nitish

# %%
a=1
b=2
c=3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c=3
print(a,b,c)
# Out:
# 3 3 3

# %% [markdown]
# #4.Keywords and identifiers

# %% [markdown]
# #5.User Input

# %%
fnum = int(input('Enter First Number'))
snum = int(input('Enter Second Number'))
# print(type(fnum),type(fnum))
result = int(fnum) + int(snum)
print(result)
print(type(fnum))
# Out:
# Enter First Number56
# Enter Second Number65
# 121
# <class 'int'>

# %%
input('Enter Email')
# Out:
# Enter Emailnitish@gmail.com
# 'nitish@gmail.com'

# %% [markdown]
# #Type Conversion

# %%
#implicit

# %%
#explicit

# %% [markdown]
# #Literals

# %%
a = 0b1010#binary
b = 100
c = 0o310#octal
d = 0x12c#hexadecimal

# %%
a = None
print(a)
# Out:
# None
